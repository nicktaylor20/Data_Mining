# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

# %%
df = pd.read_csv(r'C:\Users\nickm\OneDrive\Documents\GitHub\dsc520\data\nytimes\covid-19-data\us-states_south.csv')

# %%
df
# Out:
#        date           state  fips  cases  deaths
# 0    20-Feb           Texas    48      1       0
# 1    20-Feb           Texas    48      2       0
# 2    20-Feb           Texas    48      2       0
# 3    20-Feb           Texas    48      2       0
# 4    20-Feb           Texas    48      2       0
# ..      ...             ...   ...    ...     ...
# 634  20-Apr  North Carolina    37   8830     309
# 635  20-Apr  South Carolina    45   5490     174
# 636  20-Apr       Tennessee    47   9493     190
# 637  20-Apr           Texas    48  25206     676
# 638  20-Apr        Virginia    51  12970     448
#
# [639 rows x 5 columns]

# %% [markdown]
# # Rank number: 3 Multi-Plot

# %%
#Multiplot 
x1 = df['deaths']
x2 = df['deaths']

y1 = df['date']
y2 = df['state']

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('Covid Death Toll by Date and State')
figsize=(30,30)

ax1.plot(x1, y1)
ax1.set_ylabel('Dates')

ax2.barh(y2, x2)
ax2.set_xlabel('Number of Deaths')
ax2.set_ylabel('State')

plt.show()

# %% [markdown]
# # Rank Number: 2 Bar Chart

# %%
plt.barh(df['state'], df['deaths'])
plt.title('US Covid Deaths in Southern States')
plt.xlabel('Number of Deaths')
plt.ylabel('State')

# %% [markdown]
# # Rank Number: 1 Pie Chart

# %%
df.groupby(['state']).sum().plot(kind='pie', y='deaths',startangle=90,
figsize=(20,15), autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='deaths'>
